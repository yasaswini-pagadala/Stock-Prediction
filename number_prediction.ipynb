# %% [markdown]
# # Predicting handwritten data using cnn method

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
from keras.layers import Dropout,Dense, Flatten,Conv2D,MaxPooling2D
from keras.models import Sequential
import pandas as pd

# %%
#reading mnist data and splitting into test and train
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()

# %%
#normalizing data
x_train=tf.keras.utils.normalize(x_train, axis=1)
x_test=tf.keras.utils.normalize(x_test, axis=1)

# %%
#reshaping data for modelling
xtrain=x_train.reshape(-1,28,28,1)
xtest=x_test.reshape(-1,28,28,1)

# %%
# building the model
model=Sequential()
model.add(Conv2D(64, (3,3), input_shape = xtrain.shape[1:], activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss="sparse_categorical_crossentropy", optimizer='adam',metrics=['accuracy'])
model.fit(xtrain,y_train,epochs=10,validation_split=0.3)
# Out:
# Epoch 1/10
# 1313/1313 [==============================] - 32s 24ms/step - loss: 0.3381 - accuracy: 0.8947 - val_loss: 0.1426 - val_accuracy: 0.9571
# Epoch 2/10
# 1313/1313 [==============================] - 30s 23ms/step - loss: 0.1050 - accuracy: 0.9674 - val_loss: 0.0970 - val_accuracy: 0.9706
# Epoch 3/10
# 1313/1313 [==============================] - 31s 24ms/step - loss: 0.0771 - accuracy: 0.9763 - val_loss: 0.0727 - val_accuracy: 0.9771
# Epoch 4/10
# 1313/1313 [==============================] - 33s 25ms/step - loss: 0.0576 - accuracy: 0.9823 - val_loss: 0.0902 - val_accuracy: 0.9729
# Epoch 5/10
# 1313/1313 [==============================] - 33s 25ms/step - loss: 0.0485 - accuracy: 0.9849 - val_loss: 0.0688 - val_accuracy: 0.9798
# Epoch 6/10
# 1313/1313 [==============================] - 31s 23ms/step - loss: 0.0408 - accuracy: 0.9875 - val_loss: 0.0790 - val_accuracy: 0.9771
# Epoch 7/10
# ...

# %%
#predicting values for test data
predictions=model.predict(xtest)
predict=[np.argmax(x) for x in predictions]
df=pd.DataFrame({"actual_test":y_test,"predicted_test":predict})
# Out:
# 313/313 [==============================] - 3s 8ms/step

# %%
df
# Out:
#       actual_test  predicted_test
# 0               7               7
# 1               2               2
# 2               1               1
# 3               0               0
# 4               4               4
# ...           ...             ...
# 9995            2               2
# 9996            3               3
# 9997            4               4
# 9998            5               5
# 9999            6               6
#
# [10000 rows x 2 columns]

# %%
#checking the model for other images
img=cv2.imread("0.png")
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img,cmap=plt.cm.binary)
resize=cv2.resize(gray,(28,28),interpolation=cv2.INTER_AREA)
resize=tf.keras.utils.normalize(resize, axis=1)
n=model.predict(resize.reshape(-1,28,28,1))
np.argmax(n)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 4

# %%
img1=cv2.imread("1.png")
gray1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
plt.imshow(img1,cmap=plt.cm.binary)
resize1=cv2.resize(gray1,(28,28),interpolation=cv2.INTER_AREA)
resize1=tf.keras.utils.normalize(resize1, axis=1)
n1=model.predict(resize1.reshape(-1,28,28,1))
np.argmax(n1)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1

# %%
img2=cv2.imread("2.png")
gray2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
plt.imshow(img2,cmap=plt.cm.binary)
resize2=cv2.resize(gray2,(28,28),interpolation=cv2.INTER_AREA)
resize2=tf.keras.utils.normalize(resize2, axis=1)
n2=model.predict(resize2.reshape(-1,28,28,1))
np.argmax(n2)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 2

# %%
img3=cv2.imread("3.png")
gray3=cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
plt.imshow(img3,cmap=plt.cm.binary)
resize3=cv2.resize(gray3,(28,28),interpolation=cv2.INTER_AREA)
resize3=tf.keras.utils.normalize(resize3, axis=1)
n3=model.predict(resize3.reshape(-1,28,28,1))
np.argmax(n3)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 3

# %%
img4=cv2.imread("4.png")
gray4=cv2.cvtColor(img4,cv2.COLOR_BGR2GRAY)
plt.imshow(img4,cmap=plt.cm.binary)
resize4=cv2.resize(gray4,(28,28),interpolation=cv2.INTER_AREA)
resize4=tf.keras.utils.normalize(resize4, axis=1)
n4=model.predict(resize4.reshape(-1,28,28,1))
np.argmax(n4)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 4

# %%
img5=cv2.imread("5.png")
gray5=cv2.cvtColor(img5,cv2.COLOR_BGR2GRAY)
plt.imshow(img5,cmap=plt.cm.binary)
resize5=cv2.resize(gray5,(28,28),interpolation=cv2.INTER_AREA)
resize5=tf.keras.utils.normalize(resize5, axis=1)
n5=model.predict(resize5.reshape(-1,28,28,1))
np.argmax(n5)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 5

# %%
img6=cv2.imread("6.png")
gray6=cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
plt.imshow(img6,cmap=plt.cm.binary)
resize6=cv2.resize(gray6,(28,28),interpolation=cv2.INTER_AREA)
resize6=tf.keras.utils.normalize(resize6, axis=1)
n6=model.predict(resize6.reshape(-1,28,28,1))
np.argmax(n6)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 6

# %%
img7=cv2.imread("7.png")
gray7=cv2.cvtColor(img7,cv2.COLOR_BGR2GRAY)
plt.imshow(img7,cmap=plt.cm.binary)
resize7=cv2.resize(gray7,(28,28),interpolation=cv2.INTER_AREA)
resize7=tf.keras.utils.normalize(resize7, axis=1)
n7=model.predict(resize7.reshape(-1,28,28,1))
np.argmax(n7)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 3

# %%
img8=cv2.imread("8.png")
gray8=cv2.cvtColor(img8,cv2.COLOR_BGR2GRAY)
plt.imshow(img8,cmap=plt.cm.binary)
resize8=cv2.resize(gray8,(28,28),interpolation=cv2.INTER_AREA)
resize8=tf.keras.utils.normalize(resize8, axis=1)
n8=model.predict(resize8.reshape(-1,28,28,1))
np.argmax(n8)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 8

# %%
img9=cv2.imread("9.png")
gray9=cv2.cvtColor(img9,cv2.COLOR_BGR2GRAY)
plt.imshow(img9,cmap=plt.cm.binary)
resize9=cv2.resize(gray9,(28,28),interpolation=cv2.INTER_AREA)
resize9=tf.keras.utils.normalize(resize9, axis=1)
n9=model.predict(resize9.reshape(-1,28,28,1))
np.argmax(n9)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 9
